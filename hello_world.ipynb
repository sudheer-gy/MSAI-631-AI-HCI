# %%
# Hello World - MSAI-631 Development Environment Setup
# Author: Sudheer Godugu

def hello_world():
    message = "Hello, World! My MSAI-631 development environment is ready."
    print(message)
    return message

hello_world()
# Out:
# Hello, World! My MSAI-631 development environment is ready.
# 'Hello, World! My MSAI-631 development environment is ready.'

# %%
# Verify environment details
import sys
import platform

print(f"Python version: {sys.version}")
print(f"Operating System: {platform.system()} {platform.version()}")
print(f"Jupyter running successfully!")
# Out:
# Python version: 3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]
# Operating System: Windows 10.0.26100
# Jupyter running successfully!
